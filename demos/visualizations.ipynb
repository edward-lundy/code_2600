# %% [markdown]
# # Demo on Visualizations
# This code accompanies the lecture on visualizations using matplotlib.

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Pie Charts

# %%
types = ["pumpkin", "pecan", "apple", "sweet potato", 
         "chocolate", "cherry", "blueberry", "Boston cream", 
         "key lime", "banana cream", "strawberry", "peanut butter",
         "coconut cream", "lemon meringue", "peach", "rhubarb",
         "other"]
percents = [23, 14, 12, 8, 6, 5, 5, 3, 3, 3, 3, 3, 3, 3, 2, 2, 3]

# %%
# Draw a simple pie chart
plt.pie(percents)
plt.show()

# %%
# Define a range of colors
colors = plt.get_cmap('Greens')(np.linspace(0.7, 0.2, len(percents)))

# Create a figure and axes
fig, ax = plt.subplots()

# Create the pie chart
ax.pie(percents, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

# Include a legend
ax.legend(types, loc="right")

# Adjust the axes
ax.set(xlim=(0, 12), xticks=np.arange(1, 8),
       ylim=(0, 9), yticks=np.arange(1, 8))
ax.tick_params(left = False, labelleft = False, 
               bottom = False, labelbottom = False)
ax.set(title="Pie of Pies")

plt.show()

# %% [markdown]
# ## Bar Charts

# %%
shows = ["The Pitt", "Hacks", "Widow's Bay", "Pluribus", "Beef", "Saturday Night Live"]
num_emmy_noms = [12, 7, 7, 6, 3, 1]

# %%
# Draw a simple bar chart
plt.bar(range(len(shows)), num_emmy_noms)

plt.title("2026 Primetime Emmy Awards")
plt.ylabel("Number of Major Nominations")

plt.xticks(range(len(shows)), shows)

plt.show()

# %%
# Draw a horizontal bar chart
plt.barh(range(len(shows)), num_emmy_noms)

plt.title("2026 Primetime Emmy Awards")
plt.xlabel("Number of Major Nominations")

plt.yticks(range(len(shows)), shows)

plt.show()

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Create the bars
bar = ax.bar(shows, num_emmy_noms, width=.8)

# Adjust the axes and labels
ax.set(title='2026 Primetime Emmy Awards', 
       ylabel='Number of Major Nominations', ylim=(0, 14))
ax.set_xticklabels(shows, rotation=90)
ax.bar_label(bar, num_emmy_noms)

plt.show()
# Out:
# C:\Users\lundy\AppData\Local\Temp\ipykernel_4304\1423863881.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(shows, rotation=90)

# %%
emmys = {
    'Snubs': np.array([2, 6, 1, 4, 3]),
    'Wins': np.array([10, 1, 6, 2, 0]),
}

fig, ax = plt.subplots()
bottom = np.zeros(5)

for category, count in emmys.items():
    p = ax.bar(shows, count, width=.8, label=category, bottom=bottom)
    bottom += count

    ax.bar_label(p, label_type='center')
    
ax.set_xticklabels(shows, rotation=90)
ax.set_title('Primetime Emmy Nominations and Wins')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7 bottom = np.zeros(5)
#       9 for category, count in emmys.items():
# ---> 10     p = ax.bar(shows, count, width=.8, label=category, bottom=bottom)
#      11     bottom += count
#      13     ax.bar_label(p, label_type='center')
#
# File c:\Users\lundy\anaconda3\envs\islp\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\lundy\anaconda3\envs\islp\Lib\site-packages\matplotlib\axes\_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580     if yerr is not None:
#    2581         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2583 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2584     # Make args iterable too.
#    2585     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2587 # Now that units have been converted, set the tick locations.
#    2588 if orientation == 'vertical':
#
# File c:\Users\lundy\anaconda3\envs\islp\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:544, in broadcast_arrays(subok, *args)
#     537 # nditer is not used here to avoid the limit of 32 arrays.
#     538 # Otherwise, something like the following one-liner would suffice:
#     539 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     540 #                  order='C').itviews
#     542 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 544 shape = _broadcast_shape(*args)
#     546 result = [array if array.shape == shape
#     547           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     548                           for array in args]
#     549 return tuple(result)
#
# File c:\Users\lundy\anaconda3\envs\islp\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:419, in _broadcast_shape(*args)
#     414 """Returns the shape of the arrays that would result from broadcasting the
#     415 supplied arrays against each other.
#     416 """
#     417 # use the old-iterator because np.nditer does not handle size 0 arrays
#     418 # consistently
# --> 419 b = np.broadcast(*args[:32])
#     420 # unfortunately, it cannot handle 32 or more arguments directly
#     421 for pos in range(32, len(args), 31):
#     422     # ironically, np.broadcast does not properly handle np.broadcast
#     423     # objects (it treats them as scalars)
#     424     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (6,) and arg 1 with shape (5,).

# %% [markdown]
# ### Caution with bar charts

# %%
mentions = [500, 495]
years = [2025, 2026]

# %%
plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("Number of times I heard someone say 'data science'")

plt.axis([2024.5, 2026.5, 490, 505])
plt.title("Look at the 'huge' increase!")
plt.show()

# %%
plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("Number of times I heard someone say 'data science'")

plt.axis([2024.5, 2026.5, 490, 505])
plt.title("Not so huge anymore")
plt.show()

# %% [markdown]
# ## Line Charts

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3, 21322.9]

# %%
# Draw a simple line chart
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of Dollars")

plt.show()

# %% [markdown]
# ### Multiple lines

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x+y for x,y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
plt.plot(xs, variance,     'b-',  label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error,  'g:',  label='total error')

plt.legend(loc=9)
plt.xlabel("model complexity")
plt.xticks([])
plt.title("Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ## Boxplots

# %% [markdown]
# ### Create data
# We'll generate some random data to use to practice making boxplots.

# %%
# Always specify a seed so that the data can be regenerated
np.random.seed(314)
# We will create 3 columns with 100 observations in each.
fake_data = np.random.normal((3,5,6), (1,0.5,2), (100,3))

# %%
fig, ax = plt.subplots()
ax.boxplot(fake_data,
           positions=[2,4,6],
           widths=1.5,
           patch_artist=True,
           showmeans=False,
           showfliers=False,
           medianprops={"color": "white", "linewidth": 0.5},
           boxprops={"facecolor": "blue", "edgecolor": "black", "linewidth": 0.5},
           whiskerprops={"color": "black", "linewidth": 1.5}, 
           capprops={"color": "green", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1,8),
       ylim=(0, 12), yticks=np.arange(1,12))
ax.set_xticklabels(["","Col1","","Col2","","Col3",""])
ax.set_title("Boxplots of Normal Distributions")

plt.show()

# %% [markdown]
# ## Histograms

# %%
# Extract the first column from the array we created earlier
column1 = fake_data[:,0]

# %%
histogram = plt.hist(column1, bins=6)
plt.title("Column 1 Distribution")
plt.show()

# %%
print("counts:",histogram[0])
print("bins:",histogram[1])

# %% [markdown]
# ## Scatterplots

# %%
# Some data: social media engagement?
friends = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]

# Most basic scatter plot
plt.scatter(friends, minutes)
plt.show()

# %%
# Let's add a bunch of labels
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                 xy=(friend_count, minute_count), 
                 xytext=(5,-5),
                 textcoords='offset points')
plt.title("Social Media Engagement")
plt.xlabel("Number of Friends")
plt.ylabel("Daily Minutes on Site")
plt.show()

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

# The axes that will be given automatically are fit to each array 
plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("Test 1 Grade")
plt.ylabel("Test 2 Grade")
plt.show()

# %%
# Equally spaced axes can avoid misleading conclusions about spread
plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Are Comparable")
plt.xlabel("Test 1 Grade")
plt.ylabel("Test 2 Grade")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Contour Maps

# %%
# Create a 3-dimensional grid of data
delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

# %%
# It might be helpful to first understand what X, Y, Z are
X, Y, Z

# %%
import matplotlib.cm as cm

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Simplest default with labels')
